# %%
# !pip install tika
# Out:
# ...
#   Created wheel for tika: filename=tika-1.24-cp36-none-any.whl size=32885 sha256=a8dc596999f188cb83daa2a61bc9f0c3563608b638282b2df379fcbd77a2ecaf
#   Stored in directory: /root/.cache/pip/wheels/73/9c/f5/0b1b738442fc2a2862bef95b908b374f8e80215550fb2a8975
# Successfully built tika
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-8b182f89-69cf-4d87-9494-52abda0118b2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8b182f89-69cf-4d87-9494-52abda0118b2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving XS1569804120.pdf to XS1569804120.pdf
# ...

# %%
from tika import parser
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
raw = parser.from_file('/content/XS1569804120.pdf')
# Out:
# 2020-07-08 04:45:10,098 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server/1.24/tika-server-1.24.jar to /tmp/tika-server.jar.
# 2020-07-08 04:45:19,309 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server/1.24/tika-server-1.24.jar.md5 to /tmp/tika-server.jar.md5.
# 2020-07-08 04:45:21,135 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...

# %%
print(raw['content'])
# Out:
# z3pobdg1.DOCX
#
#
# - 1 -
#
# Execution Version
#
# PRICING SUPPLEMENT
#
# Pricing Supplement dated 9 May 2017
#
# JPMorgan Chase & Co.
#
# Structured Products Programme for the issuance of Notes, Warrants and Certificates
#
# EUR 30,000,000 15-Year 1.735% p.a. Fixed Coupon Notes due May 2032
#
# (the "Securities" or the "Notes")
#
# The offering circular dated 26 April 2017 (the "Offering Circular") (as completed and (if applicable) amended
#
# by this Pricing Supplement) has been prepared on the basis that any offer of Securities in any Member State of
#
# the European Economic Area which has implemented the Prospectus Directive (each, a "Relevant Member
#
# State") will be made pursuant to an exemption under the Prospectus Directive, as implemented in that Relevant
#
# Member State, from the requirement to publish a prospectus for offers of the Securities. The expression
#
# "Prospectus Directive" means Directive 2003/71/EC (and amendments thereto, including by Directive
#
# ...

# %%
def give_count(text):

  doc = nlp(text)

  currency  = {
    'AED':['AED'],
    'AFN':['AFN'],
    'ALL':['ALL'] ,
    'AMD':['AMD'] ,
    'ANG':['ANG'] ,
    'AOA':['AOA'] ,
    'ARS':['ARS'] ,
    'AUD':['AUD'] ,
    'AWG':['AWG'] ,
    'AZN':['AZN'] ,
    'BAM':['BAM'] ,
    'BBD':['BBD'] ,
    'BDT':['BDT'] ,
    'BGN':['BGN'] ,
    'BHD':['BHD'] ,
    'BIF':['BIF'] ,
    'BMD':['BMD'] ,
    'BND':['BND'] ,
    'BOB':['BOB'] ,
    'BOV':['BOV'] ,
    'BRL':['BRL'] ,
    'BSD':['BSD'] ,
    'BTN':['BTN'] ,
    'BWP':['BWP'] ,
    'BYN':['BYN'] ,
    'BZD':['BZD'] ,
    'CAD':['Canada','Canadian','C$','CA$'],
    'CDF':['CDF'] ,
    'CHE':['CHE'] ,
    'CHF':['CHF'] ,
    'CHW':['CHW'] ,
    'CLF':['CLF'] ,
    'CLP':['CLP'] ,
    'CNY':['CNY'] ,
    'COP':['COP'] ,
    'COU':['COU'] ,
    'CRC':['CRC'] ,
    'CUC':['CUC'] ,
    'CUP':['CUP'] ,
    'CVE':['CVE'] ,
    'CZK':['CZK'] ,
    'DJF':['DJF'] ,
    'DKK':['DKK'] ,
    'DOP':['DOP'] ,
    'DZD':['DZD'] ,
    'EGP':['EGP'] ,
    'ERN':['ERN'] ,
    'ETB':['ETB'] ,
    'EUR':['€','EUR'] ,
    'FJD':['FJD'] ,
    'FKP':['FKP'] ,
    'GBP':['£'] ,
    'GEL':['GEL'] ,
    'GHS':['GHS'] ,
    'GIP':['GIP'] ,
    'GMD':['GMD'] ,
    'GNF':['GNF'] ,
    'GTQ':['GTQ'] ,
    'GYD':['GYD'] ,
    'HKD':['HKD'] ,
    'HNL':['HNL'] ,
    'HRK':['HRK'] ,
    'HTG':['HTG'] ,
    'HUF':['HUF'] ,
    'IDR':['IDR'] ,
    'ILS':['ILS'] ,
    'INR':['₹','INR'] ,
    'IQD':['IQD'] ,
    'IRR':['IRR'] ,
    'ISK':['ISK'] ,
    'JMD':['JMD'] ,
    'JOD':['JOD'] ,
    'JPY':['JPY'] ,
    'KES':['KES'] ,
    'KGS':['KGS'] ,
    'KHR':['KHR'] ,
    'KMF':['KMF'] ,
    'KPW':['KPW'] ,
    'KRW':['KRW'] ,
    'KWD':['KWD'] ,
    'KYD':['KYD'] ,
    'KZT':['KZT'] ,
    'LAK':['LAK'] ,
    'LBP':['LBP'] ,
    'LKR':['LKR'] ,
    'LRD':['LRD'] ,
    'LSL':['LSL'] ,
    'LYD':['LYD'] ,
    'MAD':['MAD'] ,
    'MDL':['MDL'] ,
    'MGA':['MGA'] ,
    'MKD':['MKD'] ,
    'MMK':['MMK'] ,
    'MNT':['MNT'] ,
    'MOP':['MOP'] ,
    'MRU':['MRU'] ,
    'MUR':['MUR'] ,
    'MVR':['MVR'] ,
    'MWK':['MWK'] ,
    'MXN':['MXN'] ,
    'MXV':['MXV'] ,
    'MYR':['MYR'] ,
    'MZN':['MZN'] ,
    'NAD':['NAD'] ,
    'NGN':['NGN'] ,
    'NIO':['NIO'] ,
    'NOK':['NOK'] ,
    'NPR':['NPR'] ,
    'NZD':['NZD'] ,
    'OMR':['OMR'] ,
    'PAB':['PAB'] ,
    'PEN':['PEN'] ,
    'PGK':['PGK'] ,
    'PHP':['PHP'] ,
    'PKR':['PKR'] ,
    'PLN':['PLN'] ,
    'PYG':['PYG'] ,
    'QAR':['QAR'] ,
    'RON':['RON'] ,
    'RSD':['RSD'] ,
    'RUB':['RUB'] ,
    'RWF':['RWF'] ,
    'SAR':['SAR'] ,
    'SBD':['SBD'] ,
    'SCR':['SCR'] ,
    'SDG':['SDG'] ,
    'SEK':['SEK'] ,
    'SGD':['SGD'] ,
    'SHP':['SHP'] ,
    'SLL':['SLL'] ,
    'SOS':['SOS'] ,
    'SRD':['SRD'] ,
    'SSP':['SSP'] ,
    'STN':['STN'] ,
    'SVC':['SVC'] ,
    'SYP':['SYP'] ,
    'SZL':['SZL'] ,
    'THB':['THB'] ,
    'TJS':['TJS'] ,
    'TMT':['TMT'] ,
    'TND':['TND'] ,
    'TOP':['TOP'] ,
    'TRY':['TRY'] ,
    'TTD':['TTD'] ,
    'TWD':['TWD'] ,
    'TZS':['TZS'] ,
    'UAH':['UAH'] ,
    'UGX':['UGX'] ,
    'USD':['United States of America','USD','USA','US$','U.S.'],
    'USN':['USN'] ,
    'UYI':['UYI'] ,
    'UYU':['UYU'] ,
    'UYW':['UYW'] ,
    'UZS':['UZS'] ,
    'VES':['VES'] ,
    'VND':['VND'] ,
    'VUV':['VUV'] ,
    'WST':['WST'] ,
    'XAF':['XAF'] ,
    'XAG':['XAG'] ,
    'XAU':['XAU'] ,
    'XBA':['XBA'] ,
    'XBB':['XBB'] ,
    'XBC':['XBC'] ,
    'XBD':['XBD'] ,
    'XCD':['XCD'] ,
    'XDR':['XDR'] ,
    'XOF':['XOF'] ,
    'XPD':['XPD'] ,
    'XPF':['XPF'] ,
    'XPT':['XPT'] ,
    'XSU':['XSU'] ,
    'XTS':['XTS'] ,
    'XUA':['XUA'] ,
    'XXX':['XXX'] ,
    'YER':['YER'] ,
    'ZAR':['ZAR'] ,
    'ZMW':['ZMW'] ,
  }
  
  count = {
    'AED':0,
    'AFN':0 ,
    'ALL':0 ,
    'AMD':0 ,
    'ANG':0 ,
    'AOA':0 ,
    'ARS':0 ,
    'AUD':0 ,
    'AWG':0 ,
    'AZN':0 ,
    'BAM':0 ,
    'BBD':0 ,
    'BDT':0 ,
    'BGN':0 ,
    'BHD':0 ,
    'BIF':0 ,
    'BMD':0 ,
    'BND':0 ,
    'BOB':0 ,
    'BOV':0 ,
    'BRL':0 ,
    'BSD':0 ,
    'BTN':0 ,
    'BWP':0 ,
    'BYN':0 ,
    'BZD':0 ,
    'CAD':0 ,
    'CDF':0 ,
    'CHE':0 ,
    'CHF':0 ,
    'CHW':0 ,
    'CLF':0 ,
    'CLP':0 ,
    'CNY':0 ,
    'COP':0 ,
    'COU':0 ,
    'CRC':0 ,
    'CUC':0 ,
    'CUP':0 ,
    'CVE':0 ,
    'CZK':0 ,
    'DJF':0 ,
    'DKK':0 ,
    'DOP':0 ,
    'DZD':0 ,
    'EGP':0 ,
    'ERN':0 ,
    'ETB':0 ,
    'EUR':0 ,
    'FJD':0 ,
    'FKP':0 ,
    'GBP':0 ,
    'GEL':0 ,
    'GHS':0 ,
    'GIP':0 ,
    'GMD':0 ,
    'GNF':0 ,
    'GTQ':0 ,
    'GYD':0 ,
    'HKD':0 ,
    'HNL':0 ,
    'HRK':0 ,
    'HTG':0 ,
    'HUF':0 ,
    'IDR':0 ,
    'ILS':0 ,
    'INR':0 ,
    'IQD':0 ,
    'IRR':0 ,
    'ISK':0 ,
    'JMD':0 ,
    'JOD':0 ,
    'JPY':0 ,
    'KES':0 ,
    'KGS':0 ,
    'KHR':0 ,
    'KMF':0 ,
    'KPW':0 ,
    'KRW':0 ,
    'KWD':0 ,
    'KYD':0 ,
    'KZT':0 ,
    'LAK':0 ,
    'LBP':0 ,
    'LKR':0 ,
    'LRD':0 ,
    'LSL':0 ,
    'LYD':0 ,
    'MAD':0 ,
    'MDL':0 ,
    'MGA':0 ,
    'MKD':0 ,
    'MMK':0 ,
    'MNT':0 ,
    'MOP':0 ,
    'MRU':0 ,
    'MUR':0 ,
    'MVR':0 ,
    'MWK':0 ,
    'MXN':0 ,
    'MXV':0 ,
    'MYR':0 ,
    'MZN':0 ,
    'NAD':0 ,
    'NGN':0 ,
    'NIO':0 ,
    'NOK':0 ,
    'NPR':0 ,
    'NZD':0 ,
    'OMR':0 ,
    'PAB':0 ,
    'PEN':0 ,
    'PGK':0 ,
    'PHP':0 ,
    'PKR':0 ,
    'PLN':0 ,
    'PYG':0 ,
    'QAR':0 ,
    'RON':0 ,
    'RSD':0 ,
    'RUB':0 ,
    'RWF':0 ,
    'SAR':0 ,
    'SBD':0 ,
    'SCR':0 ,
    'SDG':0 ,
    'SEK':0 ,
    'SGD':0 ,
    'SHP':0 ,
    'SLL':0 ,
    'SOS':0 ,
    'SRD':0 ,
    'SSP':0 ,
    'STN':0 ,
    'SVC':0 ,
    'SYP':0 ,
    'SZL':0 ,
    'THB':0 ,
    'TJS':0 ,
    'TMT':0 ,
    'TND':0 ,
    'TOP':0 ,
    'TRY':0 ,
    'TTD':0 ,
    'TWD':0 ,
    'TZS':0 ,
    'UAH':0 ,
    'UGX':0 ,
    'USD':0 ,
    'USN':0 ,
    'UYI':0 ,
    'UYU':0 ,
    'UYW':0 ,
    'UZS':0 ,
    'VES':0 ,
    'VND':0 ,
    'VUV':0 ,
    'WST':0 ,
    'XAF':0 ,
    'XAG':0 ,
    'XAU':0 ,
    'XBA':0 ,
    'XBB':0 ,
    'XBC':0 ,
    'XBD':0 ,
    'XCD':0 ,
    'XDR':0 ,
    'XOF':0 ,
    'XPD':0 ,
    'XPF':0 ,
    'XPT':0 ,
    'XSU':0 ,
    'XTS':0 ,
    'XUA':0 ,
    'XXX':0 ,
    'YER':0 ,
    'ZAR':0 ,
    'ZMW':0 ,
    'ZWL':0
    }

  for cur in currency.keys():
    for token in doc:
      for ele in currency[cur]:
        if(ele in str(token)):
            count[cur] = count[cur]+1
  
  key = ''
  maxim = 0
  total = 0
  for cur in count.keys():
    total = count[cur]+total
    if(count[cur]>maxim):
      key = cur
      maxim = count[cur]
  
  for cur in count.keys():
    count[cur] = count[cur]/total
  print(count)
  return key

# %%
give_count(raw['content'])
# Out:
# {'AED': 0.0, 'AFN': 0.0, 'ALL': 0.0, 'AMD': 0.0, 'ANG': 0.0, 'AOA': 0.0, 'ARS': 0.0, 'AUD': 0.0, 'AWG': 0.0, 'AZN': 0.0, 'BAM': 0.0, 'BBD': 0.0, 'BDT': 0.0, 'BGN': 0.0, 'BHD': 0.0, 'BIF': 0.0, 'BMD': 0.0, 'BND': 0.0, 'BOB': 0.0, 'BOV': 0.0, 'BRL': 0.0, 'BSD': 0.0, 'BTN': 0.0, 'BWP': 0.0, 'BYN': 0.0, 'BZD': 0.0, 'CAD': 0.0, 'CDF': 0.0, 'CHE': 0.0, 'CHF': 0.0, 'CHW': 0.0, 'CLF': 0.0, 'CLP': 0.0, 'CNY': 0.0, 'COP': 0.0, 'COU': 0.0, 'CRC': 0.0, 'CUC': 0.0, 'CUP': 0.0, 'CVE': 0.0, 'CZK': 0.0, 'DJF': 0.0, 'DKK': 0.0, 'DOP': 0.0, 'DZD': 0.0, 'EGP': 0.0, 'ERN': 0.047619047619047616, 'ETB': 0.0, 'EUR': 0.6190476190476191, 'FJD': 0.0, 'FKP': 0.0, 'GBP': 0.0, 'GEL': 0.0, 'GHS': 0.0, 'GIP': 0.0, 'GMD': 0.0, 'GNF': 0.0, 'GTQ': 0.0, 'GYD': 0.0, 'HKD': 0.0, 'HNL': 0.0, 'HRK': 0.0, 'HTG': 0.0, 'HUF': 0.0, 'IDR': 0.0, 'ILS': 0.0, 'INR': 0.0, 'IQD': 0.0, 'IRR': 0.0, 'ISK': 0.047619047619047616, 'JMD': 0.0, 'JOD': 0.0, 'JPY': 0.0, 'KES': 0.0, 'KGS': 0.0, 'KHR': 0.0, 'KMF': 0.0, 'KPW': 0.0, 'KRW': 0.0, 
# ...
